# %% [markdown]
# # Simple Agent Showcase
#
# This notebook demonstrates how to use the simple agent defined in `app/agent.py`.

# %%
import sys
import os

# Add the parent directory to sys.path to ensure we can import the app module
sys.path.append(os.path.abspath('..'))

from app.agent import root_agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai import types

# %%
# Setup session and runner
session_service = InMemorySessionService()
session = session_service.create_session_sync(user_id="notebook_user", app_name="notebook_app")
runner = Runner(agent=root_agent, session_service=session_service, app_name="notebook_app")
# Out:
# Deprecated. Please migrate to the async method.

# %%
# Define a query
query_text = "What is the weather in SF?"
message = types.Content(role="user", parts=[types.Part.from_text(text=query_text)])

print(f"User: {query_text}")

# Run the agent
events = list(runner.run(
    new_message=message,
    user_id="notebook_user",
    session_id=session.id
))

# Display the response
print("Agent:")
for event in events:
    if event.content and event.content.parts:
        for part in event.content.parts:
            if part.text:
                print(part.text)
# Out:
# User: What is the weather in SF?
# Agent:
# User wants weather. Use get_weather.
# We provided a simulated response.
# **San Francisco Weather (current)**
# - Temperature: 60 °F (16 °C)
# - Wind: 6 mph from the west
# - Conditions: Foggy and overcast
# - Humidity: 73%
# - Chance of precipitation: 5%
#
# Let me know if you'd like a forecast for the next few days or anything else!
